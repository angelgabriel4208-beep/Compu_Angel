# %%
import numpy as np
import pandas as pd

df_hospital = pd.read_csv(r"C:\Users\computacion\Downloads\descarga.csv")

dfnull = df_hospital.isnull()
print(df_hospital)
print(dfnull)

dfSum = df_hospital.isnull().sum()

print(dfSum)

dfCorrectos = df_hospital.notnull()

print(dfCorrectos)

print(df_hospital.head)

print(df_hospital.tail)

print(df_hospital.describe())

print(df_hospital.shape)
# Out:
#      ID_Paciente          Nombre  Edad   Diagnostico Fecha_Ingreso
# 0              1      Juan Perez  34.0         Gripe    2026-01-01
# 1              2     Maria Lopez  45.0      Diabetes    2026-01-02
# 2              3    Carlos Gomez   NaN      Fractura    2026-01-03
# 3              4    Ana Martinez  60.0           NaN    2026-01-04
# 4              5  Luis Hernandez  50.0          Asma           NaN
# ..           ...             ...   ...           ...           ...
# 195          196   Sofia Ramirez   NaN         Gripe    2026-07-14
# 196          197    Pedro Torres  58.0      Diabetes           NaN
# 197          198    Lucia Flores  26.0      Fractura    2026-07-16
# 198          199    Diego Rivera   NaN  Hipertension    2026-07-17
# 199          200      Elena Cruz  41.0          Asma           NaN
#
# [200 rows x 5 columns]
#      ID_Paciente  Nombre   Edad  Diagnostico  Fecha_Ingreso
# 0          False   False  False        False          False
# ...
